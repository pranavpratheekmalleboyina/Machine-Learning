# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[75,72,73,77,68,66,68]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='red',marker='D')

# %%
plt.plot(x,y,color='red',marker='D',linestyle='dotted',alpha=0.4)
